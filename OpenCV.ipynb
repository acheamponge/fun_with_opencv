# %%
# %pylab notebook
import cv2
# Load an color image in grayscale
img = cv2.imread("img/2.jpg",0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cv2.imshow("image",img) # the title and path to image
cv2.waitKey(0) # Waits for the next key to be pressed

cv2.imwrite("img/2_a.jpg",img)
# Out:
# True

# %%
import os
for filename in os.listdir('img/downloads/African fashion/'):
    img = cv2.imread("img/downloads/African fashion/"+filename,0)
    cv2.imwrite("img/downloads/Grey Scale/"+filename,img)

# %%
import os
for filename in os.listdir('img/downloads/African fashion/'):
    img = cv2.imread("img/downloads/African fashion/"+filename,0)
    cv2.imwrite("img/downloads/Grey Scale/"+filename,img)

# %%
import os
for filename in os.listdir('img/downloads/African men fashion/'):
    img = cv2.imread("img/downloads/African men fashion/"+filename,0)
    cv2.imwrite("img/downloads/African men fashion Grey Scale/"+filename,img)

# %%
import os
for filename in os.listdir('img/downloads/kente/'):
    img = cv2.imread("img/downloads/kente/"+filename,0)
    cv2.imwrite("img/downloads/kente greyscale/"+filename,img)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('img/downloads/African fashion/1.jpg')
plt.imshow(img)
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('img/downloads/African men fashion/1.Wine-Dashiki-for-Men-AFRICABLOOMS.jpg')
plt.imshow(img)
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
px = img[100,100]
print(px)
# Out:
# [ 4  6 16]

# %%
img.item(10,10,2)
# Out:
# 18

# %%
print(img.size)
# Out:
# 2018112

# %%
print(img.dtype)
# Out:
# uint8

# %%
ball = img2[280:340, 330:390]
img2[273:333, 100:160] = ball

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img2 = cv2.imread('img/messi.jpg',0)
plt.imshow(img2)
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('img/1.jpg',0)
img = cv2.medianBlur(img,5)

ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)

titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('img/1.jpg',0)

# global thresholding
ret1,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# Otsu's thresholding
ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# Otsu's thresholding after Gaussian filtering
blur = cv2.GaussianBlur(img,(5,5),0)
ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# plot all the images and their histograms
images = [img, 0, th1,
          img, 0, th2,
          blur, 0, th3]
titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
          'Original Noisy Image','Histogram',"Otsu's Thresholding",
          'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]

for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np

img = cv2.imread('img/downloads/African men fashion/19.african-men-fashion-top-.jpg',0)
rows,cols = img.shape

M = np.float32([[1,0,100],[0,1,50]])
dst = cv2.warpAffine(img,M,(cols,rows))

cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img = cv2.imread('img/downloads/African men fashion/19.african-men-fashion-top-.jpg',0)
rows,cols = img.shape


M = cv2.getRotationMatrix2D((cols/2,rows/2),90,1)
dst = cv2.warpAffine(img,M,(cols,rows))

cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
